# %% [markdown]
# Lab03-1

# %% [markdown]
# chapter2 - Exercise 1

# %%
## We’ve seen that n = 42 is legal. What about 42 = n?
n = 42
print(n)
# Out:
# 42

# %%
42  = n
# Out:
#   File "<ipython-input-5-72307a49d11d>", line 1
#     42  = n
#     ^
# SyntaxError: cannot assign to literal

# %%
x = y = 1
print(x)
print(y)
# Out:
# 1
# 1

# %%
x = y = 1;
print(x)
print(y)
# Out:
# 1
# 1

# %%
x = y = 1.
print(x)
print(y)
# Out:
# 1.0
# 1.0

# %%
x**y
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-41-2bd9b4b39906> in <module>
# ----> 1 x**y
#
# OverflowError: (34, 'Result too large')

# %% [markdown]
# Exercise 2

# %%
## 1. The volume of a sphere with radius r is 4/3 π r3. What is the volume of a sphere with radius 5?
r = 5 
volume = 4/3*3.14*r**3
print(volume)
# Out:
# 523.3333333333334

# %%
## 2. Suppose the cover price of a book is $24.95, but bookstores get a 40% discount. 
## Shipping costs $3 for the first copy and 75 cents for each additional copy. 
##What is the total wholesale cost for 60 copies?

24.95*(1-0.4) +3+(60-1)*0.75
# Out:
# 62.22

# %%
## 3. If I leave my house at 6:52 am and run 1 mile at an easy pace (8:15 per mile), 
## then 3 miles at tempo (7:12 per mile) and 1 mile at easy pace again, what time do I get home for breakfast
x = ((8.15 *2) + (7.12 * 3)) * 60 
y = 6 * 60 * 60 + 52 * 60
z = (x + y)/3600
print(z)
## Therefore, he will back to home at 7:30 am
# Out:
# 7.494333333333333

# %% [markdown]
# chapter 8

# %%
##Exercise 1 
### Read the documentation of the string methods at http://docs.python.org/3/library/stdtypes.html#string-methods. 
### You might want to experiment with some of them to make sure you understand how they work. 
### Strip and replace are particularly useful.
### The documentation uses a syntax that might be confusing. For example, in find(sub[, start[, end]]), 
### the brackets indicate optional arguments. So sub is required, but start is optional, and if you include start, then end is optional.

# %%
##Exercise 2
### There is a string method called count that is similar to the function in Section 8.7. 
### Read the documentation of this method and write an invocation that counts the number of a’s in 'banana'.
def counter(word):
    return word.count('a')

counter('banana')
# Out:
# 3

# %%
## Exercise 3  
fruit = 'banana'
fruit[0:5:2]
# Out:
# 'bnn'

# %%
def is_palindrome(word):
    return word == word[::-1]

is_palindrome('bob')
# Out:
# True

# %%
## Exercise 4 

def any_lowercase1(s):
    for c in s:
        if c.islower():
            return True
        else:
            return False
    
## The islower function is used to test whether a string contains any lowercase letters. 
## If there is all lowercase, the return will be True. The python won't run the second return.  


def any_lowercase2(s):
    for c in s:
        if 'c'.islower():
            return 'True'
        else:
            return 'False'
## If the string 'c' is all lowercase, the function will return string 'True'. It only will return 'True'.

def any_lowercase3(s):
    for c in s:
        flag = c.islower()
    return flag

## Check if the last letter is lowercase

def any_lowercase4(s):
    flag = False
    for c in s:
        flag = flag or c.islower()
    return flag

## Check for the existence of lowercase letters

def any_lowercase5(s):
    for c in s:
        if not c.islower():
            return False
    return True
## Check if the string is all lowercase
# Out:
#   File "<ipython-input-22-522f4671ed69>", line 40
#     print(c)
#     ^
# IndentationError: unexpected indent

# %%
## Exercise 5

def rotate_letter(letter, n):
    """Rotates a letter by n places.  Does not change other chars.
    letter: single-letter string
    n: int
    Returns: single-letter string
    """
    if letter.isupper():
        start = ord('A')
    elif letter.islower():
        start = ord('a')
    else:
        return letter

    c = ord(letter) - start
    i = (c + n) % 26 + start
    return chr(i)


def rotate_word(word, n):
    """Rotates a word by n places.
    word: string
    n: integer
    Returns: string
    """
    res = ''
    for letter in word:
        res += rotate_letter(letter, n)
    return res


if __name__ == '__main__':
    print(rotate_word('cheer', 7))
    print(rotate_word('melon', -10))
    print(rotate_word('sleep', 9))
# Out:
# jolly
# cubed
# bunny

# %%
ord('c') - ord('a')
# Out:
# 2

# %% [markdown]
#  Lab03-2: Conditional Execution

# %%
## 1. Extend the Python [notebook] from class to prompt the user for two input values
## - The convergence criterion (i.e., percentage difference for stopping the loop)
## - A sentinel value that limits the number of draws to avoid a long running program. 
## Once the number of draws reaches this value you should have the program stop and print a message that draw limit was exceeded and report the percentage difference between the current estimate of Pi and the true value.
import random
import math
import matplotlib.pyplot as plt
pi = math.pi # our benchmark that we want to estimate using simulation
pi
# Out:
# 3.141592653589793

# %%
## 2. 
n = 0 # number of points falling in the unit circle
d = 0 # number of points falling in the unit square
while simulating:
    x = random.random()
    y = random.random()
    if x**2 + y**2 <= 1.0:
        n += 1
    d += 1
    ratio = 4 * n * 1./d
    print(ratio)
    if abs(ratio-pi) / pi <= 0.01:
        print("Draws needed: ", d)
        break
# Out:
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 3.5
# 3.5555555555555554
# 3.6
# 3.6363636363636362
# 3.6666666666666665
# 3.6923076923076925
# 3.7142857142857144
# 3.7333333333333334
# 3.75
# 3.764705882352941
# 3.5555555555555554
# 3.5789473684210527
# 3.6
# 3.619047619047619
# 3.6363636363636362
# 3.4782608695652173
# 3.3333333333333335
# 3.36
# 3.230769230769231
# 3.111111111111111
# Draws needed:  27

# %%
plt.plot(ratios[:10])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-a1b4e8b5dbd5> in <module>
# ----> 1 plt.plot(ratios[:10])
#
# NameError: name 'ratios' is not defined

# %%
n = 0 # number of points falling in the unit circle
d = 0 # number of points falling in the unit square
while simulating:
    x = random.random()
    y = random.random()
    if x**2 + y**2 <= 1.0:
        n += 1
    d += 1
    ratio = 4 * n * 1./d
    print(ratio)
    if abs(ratio-pi) / pi <= 0.001:
        print("Draws needed: ", d)
        break
# Out:
# 4.0
# 4.0
# 4.0
# 3.0
# 3.2
# 2.6666666666666665
# 2.857142857142857
# 3.0
# 3.111111111111111
# 3.2
# 3.272727272727273
# 3.3333333333333335
# 3.3846153846153846
# 3.4285714285714284
# 3.466666666666667
# 3.5
# 3.5294117647058822
# 3.5555555555555554
# 3.5789473684210527
# 3.6
# 3.4285714285714284
# 3.272727272727273
# 3.3043478260869565
# 3.3333333333333335
# 3.36
# 3.3846153846153846
# 3.4074074074074074
# 3.4285714285714284
# 3.4482758620689653
# 3.466666666666667
# 3.4838709677419355
# 3.5
# 3.515151515151515
# 3.411764705882353
# 3.4285714285714284
# 3.4444444444444446
# 3.3513513513513513
# 3.263157894736842
# 3.1794871794871793
# 3.2
# 3.2195121951219514
# 3.238095238095238
# 3.255813953488372
# 3.272727272727273
# 3.2888888888888888
# 3.3043478260869565
# 3.3191489361702127
# 3.25
# 3.2653061224489797
# 3.28
# 3.2941176470588234
# 3.3076923076923075
# 3.3207547169811322
# 3.3333333333333335
# 3.272727272727273
# 3.2857142857142856
# 3.2280701754385963
# 3.1724137931034484
# ...

# %%
n = 0 # number of points falling in the unit circle
d = 0 # number of points falling in the unit square
while simulating:
    x = random.random()
    y = random.random()
    if x**2 + y**2 <= 1.0:
        n += 1
    d += 1
    ratio = 4 * n * 1./d
    print(ratio)
    if abs(ratio-pi) / pi <= 0.0001:
        print("Draws needed: ", d)
        break
# Out:
# 4.0
# 2.0
# 2.6666666666666665
# 3.0
# 3.2
# 2.6666666666666665
# 2.857142857142857
# 3.0
# 3.111111111111111
# 3.2
# 3.272727272727273
# 3.3333333333333335
# 3.3846153846153846
# 3.4285714285714284
# 3.466666666666667
# 3.25
# 3.2941176470588234
# 3.3333333333333335
# 3.3684210526315788
# 3.4
# 3.4285714285714284
# 3.4545454545454546
# 3.4782608695652173
# 3.5
# 3.52
# 3.5384615384615383
# 3.5555555555555554
# 3.5714285714285716
# 3.586206896551724
# 3.6
# 3.6129032258064515
# 3.5
# 3.515151515151515
# 3.5294117647058822
# 3.5428571428571427
# 3.5555555555555554
# 3.5675675675675675
# 3.5789473684210527
# 3.58974358974359
# 3.5
# 3.4146341463414633
# 3.4285714285714284
# 3.441860465116279
# 3.3636363636363638
# 3.2888888888888888
# 3.3043478260869565
# 3.3191489361702127
# 3.25
# 3.2653061224489797
# 3.28
# 3.2941176470588234
# 3.3076923076923075
# 3.3207547169811322
# 3.3333333333333335
# 3.3454545454545452
# 3.2857142857142856
# 3.2280701754385963
# 3.2413793103448274
# ...

# %%
n = 0 # number of points falling in the unit circle
d = 0 # number of points falling in the unit square
while simulating:
    x = random.random()
    y = random.random()
    if x**2 + y**2 <= 1.0:
        n += 1
    d += 1
    ratio = 4 * n * 1./d
    print(ratio)
    if abs(ratio-pi) / pi <= 0.00001:
        print("Draws needed: ", d)
        break
# Out:
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 3.5555555555555554
# 3.2
# 3.272727272727273
# 3.3333333333333335
# 3.3846153846153846
# 3.4285714285714284
# 3.466666666666667
# 3.5
# 3.5294117647058822
# 3.5555555555555554
# 3.3684210526315788
# 3.2
# 3.238095238095238
# 3.272727272727273
# 3.3043478260869565
# 3.3333333333333335
# 3.36
# 3.3846153846153846
# 3.4074074074074074
# 3.4285714285714284
# 3.4482758620689653
# 3.466666666666667
# 3.3548387096774195
# 3.375
# 3.393939393939394
# 3.411764705882353
# 3.4285714285714284
# 3.4444444444444446
# 3.4594594594594597
# 3.473684210526316
# 3.4871794871794872
# 3.5
# 3.5121951219512195
# 3.5238095238095237
# 3.5348837209302326
# 3.5454545454545454
# 3.5555555555555554
# 3.5652173913043477
# 3.4893617021276597
# 3.5
# 3.4285714285714284
# 3.44
# 3.372549019607843
# 3.3846153846153846
# 3.3962264150943398
# 3.3333333333333335
# 3.3454545454545452
# 3.357142857142857
# 3.3684210526315788
# 3.3793103448275863
# 3.389830508474576
# 3.4
# ...
